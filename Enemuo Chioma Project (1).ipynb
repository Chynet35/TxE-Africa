# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.4.4

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
df = pd.DataFrame()

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# your code goes here
marvel_df = marvel_data[0:]

df = pd.DataFrame(marvel_df)
df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
df.info
# Out:
# <bound method DataFrame.info of                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.columns = [
    'Name',
    'Sex',
    'Age'
]

# %%
df
# Out:
#                 Name     Sex   Age
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
# your code goes here

marvel_df=df

# %%
marvel_df
# Out:
#                 Name     Sex   Age
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df.columns
# Out:
# Index(['Name', 'Sex', 'Age'], dtype='object')

# %%
marvel_df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# your code goes here

marvel_df.index = [
'Spider-Man', 
'Captain America',
'Wolverine',
'Iron Man',
'Thor',
'Thing',
'Mister Fantastic',
'Hulk',
'Beast',
'Invisible Woman',
'Storm',
'Namor',
'Hawkeye',
'Daredevil',
'Doctor Strange',
'Hank Pym',
'Scarlet Witch',
'Wasp',
'Black Widow',
'Vision'
]

# %%
marvel_df
# Out:
#                               Name     Sex   Age
# Spider-Man              Spider-Man    male  1962
# Captain America    Captain America    male  1941
# Wolverine                Wolverine    male  1974
# Iron Man                  Iron Man    male  1963
# Thor                          Thor    male  1963
# Thing                        Thing    male  1961
# Mister Fantastic  Mister Fantastic    male  1961
# Hulk                          Hulk    male  1962
# Beast                        Beast    male  1963
# Invisible Woman    Invisible Woman  female  1961
# Storm                        Storm  female  1975
# Namor                        Namor    male  1939
# Hawkeye                    Hawkeye    male  1964
# Daredevil                Daredevil    male  1964
# Doctor Strange      Doctor Strange    male  1963
# Hank Pym                  Hank Pym    male  1962
# Scarlet Witch        Scarlet Witch  female  1964
# Wasp                          Wasp  female  1963
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# your code goes here
marvel_df = marvel_df.drop('Name', axis=1)

# %%
marvel_df
# Out:
#                      Sex   Age
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Namor               male  1939
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Hank Pym            male  1962
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# your code goes here

marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)

# %%
marvel_df
# Out:
#                      Sex   Age
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here

marvel_df.iloc[0:5]
# Out:
#                   Sex   Age
# Spider-Man       male  1962
# Captain America  male  1941
# Wolverine        male  1974
# Iron Man         male  1963
# Thor             male  1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here

marvel_df.iloc[-5:]
# Out:
#                    Sex   Age
# Doctor Strange    male  1963
# Scarlet Witch   female  1964
# Wasp            female  1963
# Black Widow     female  1964
# Vision            male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here

marvel_df.iloc[0:5, 0]
# Out:
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: Sex, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
marvel_df
# Out:
#                      Sex   Age
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968

# %%
# your code goes here

marvel_df.iloc[[9]]
# Out:
#                     Sex   Age
# Invisible Woman  female  1961

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here

marvel_df.iloc[[0,-1]]
# Out:
#              Sex   Age
# Spider-Man  male  1962
# Vision      male  1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
marvel_df.iloc[-1]
# Out:
# Sex    male
# Age    1968
# Name: Vision, dtype: object

# %%
marvel_df.iloc[-1,-1]
# Out:
# 1968

# %%
# your code goes here

marvel_df.iloc[-1,-1] = '1964'

# %%
marvel_df
# Out:
#                      Sex   Age
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1964

# %%
marvel_df.columns[-1]
# Out:
# 'Age'

# %%
marvel_df['Age']
# Out:
# Spider-Man          1962
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Vision              1964
# Name: Age, dtype: object

# %%
marvel_df.columns = ['Sex','first_appearance']

# %%
marvel_df
# Out:
#                      Sex first_appearance
# Spider-Man          male             1962
# Captain America     male             1941
# Wolverine           male             1974
# Iron Man            male             1963
# Thor                male             1963
# Thing               male             1961
# Mister Fantastic    male             1961
# Hulk                male             1962
# Beast               male             1963
# Invisible Woman   female             1961
# Storm             female             1975
# Hawkeye             male             1964
# Daredevil           male             1964
# Doctor Strange      male             1963
# Scarlet Witch     female             1964
# Wasp              female             1963
# Black Widow       female             1964
# Vision              male             1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
marvel_df.columns
# Out:
# Index(['Sex', 'first_appearance'], dtype='object')

# %%
# your code goes here

marvel_df['years_since'] = marvel_df['first_appearance']

# %%
marvel_df
# Out:
#                      Sex first_appearance years_since
# Spider-Man          male             1962        1962
# Captain America     male             1941        1941
# Wolverine           male             1974        1974
# Iron Man            male             1963        1963
# Thor                male             1963        1963
# Thing               male             1961        1961
# Mister Fantastic    male             1961        1961
# Hulk                male             1962        1962
# Beast               male             1963        1963
# Invisible Woman   female             1961        1961
# Storm             female             1975        1975
# Hawkeye             male             1964        1964
# Daredevil           male             1964        1964
# Doctor Strange      male             1963        1963
# Scarlet Witch     female             1964        1964
# Wasp              female             1963        1963
# ...

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here

marvel_df['Sex'] = marvel_df['Sex'].map({'female': True, 'male': False})
print(marvel_df)
# Out:
#                     Sex first_appearance years_since
# Spider-Man        False             1962        1962
# Captain America   False             1941        1941
# Wolverine         False             1974        1974
# Iron Man          False             1963        1963
# Thor              False             1963        1963
# Thing             False             1961        1961
# Mister Fantastic  False             1961        1961
# Hulk              False             1962        1962
# Beast             False             1963        1963
# Invisible Woman    True             1961        1961
# Storm              True             1975        1975
# Hawkeye           False             1964        1964
# Daredevil         False             1964        1964
# Doctor Strange    False             1963        1963
# Scarlet Witch      True             1964        1964
# Wasp               True             1963        1963
# Black Widow        True             1964        1964
# ...

# %%
# your code goes here

rows_condition = [False, False, False, False, False, False, False, False, False, True, True, False, False, False, True, True, True, False]

marvel_df.loc[rows_condition]
# Out:
#                   Sex first_appearance years_since
# Invisible Woman  True             1961        1961
# Storm            True             1975        1975
# Scarlet Witch    True             1964        1964
# Wasp             True             1963        1963
# Black Widow      True             1964        1964

# %%
marvel_df
# Out:
#                     Sex first_appearance years_since
# Spider-Man        False             1962        1962
# Captain America   False             1941        1941
# Wolverine         False             1974        1974
# Iron Man          False             1963        1963
# Thor              False             1963        1963
# Thing             False             1961        1961
# Mister Fantastic  False             1961        1961
# Hulk              False             1962        1962
# Beast             False             1963        1963
# Invisible Woman    True             1961        1961
# Storm              True             1975        1975
# Hawkeye           False             1964        1964
# Daredevil         False             1964        1964
# Doctor Strange    False             1963        1963
# Scarlet Witch      True             1964        1964
# Wasp               True             1963        1963
# Black Widow        True             1964        1964
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here

rows_condition = [True, True, True, True, True, True, True, True, True, False, False, True, True, True, False, False, False, True]

marvel_df.loc[rows_condition]
# Out:
#                     Sex first_appearance years_since
# Spider-Man        False             1962        1962
# Captain America   False             1941        1941
# Wolverine         False             1974        1974
# Iron Man          False             1963        1963
# Thor              False             1963        1963
# Thing             False             1961        1961
# Mister Fantastic  False             1961        1961
# Hulk              False             1962        1962
# Beast             False             1963        1963
# Hawkeye           False             1964        1964
# Daredevil         False             1964        1964
# Doctor Strange    False             1963        1963
# Vision            False             1964        1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
marvel_df['first_appearance']
# Out:
# Spider-Man          1962
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Vision              1964
# Name: first_appearance, dtype: object

# %%
# marvel_df['first_appearance'] = marvel_df['first_appearance'].map({[ > 1970: True, < 1970: False]})
# print(marvel_df)

# %%
marvel_df.iloc[10]
# Out:
# Sex                 True
# first_appearance    1975
# years_since         1975
# Name: Storm, dtype: object

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
marvel_df.describe()
# Out:
#           Sex  first_appearance  years_since
# count      18                18           18
# unique      2                 8            8
# top     False              1963         1963
# freq       13                 5            5

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
marvel_df
# Out:
#                     Sex first_appearance years_since
# Spider-Man        False             1962        1962
# Captain America   False             1941        1941
# Wolverine         False             1974        1974
# Iron Man          False             1963        1963
# Thor              False             1963        1963
# Thing             False             1961        1961
# Mister Fantastic  False             1961        1961
# Hulk              False             1962        1962
# Beast             False             1963        1963
# Invisible Woman    True             1961        1961
# Storm              True             1975        1975
# Hawkeye           False             1964        1964
# Daredevil         False             1964        1964
# Doctor Strange    False             1963        1963
# Scarlet Witch      True             1964        1964
# Wasp               True             1963        1963
# Black Widow        True             1964        1964
# ...

# %%
# your code goes here
first_appearance = marvel_df['first_appearance']

# %%
marvel_df.head(5)
# Out:
#                    Sex first_appearance years_since
# Spider-Man       False             1962        1962
# Captain America  False             1941        1941
# Wolverine        False             1974        1974
# Iron Man         False             1963        1963
# Thor             False             1963        1963

# %%
first_appearance.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of Spider-Man          1962
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Vision              1964
# Name: first_appearance, dtype: object>

# %%
first_appearance
# Out:
# Spider-Man          1962
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Vision              1964
# Name: first_appearance, dtype: object

# %%
marvel_df.describe()
# Out:
#           Sex  first_appearance  years_since
# count      18                18           18
# unique      2                 8            8
# top     False              1963         1963
# freq       13                 5            5

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
